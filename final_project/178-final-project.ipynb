# %% [markdown]
# # CS178 Final Project
# ### Joseph Zheng
# ### Shiqi Wu
# ### Qi Hong Chen

# %%
from __future__ import division

import numpy as np

import mltools as ml
import sys
sys.path.append('code')

import matplotlib.pyplot as plt   # use matplotlib for plotting with inline plots
plt.set_cmap('jet');
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore'); # for deprecated matplotlib functions

from sklearn.model_selection import train_test_split

from sklearn.feature_selection import mutual_info_classif
import itertools

from sklearn.neighbors import KNeighborsRegressor

from sklearn.neural_network import MLPRegressor

from sklearn.ensemble import AdaBoostRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ddf382abc1f2> in <module>
#       3 import numpy as np
#       4
# ----> 5 import mltools as ml
#       6 import sys
#       7 sys.path.append('code')
#
# ModuleNotFoundError: No module named 'mltools'

# %% [markdown]
# # KNN Classifier

# %%
class KNN(ml.base.classifier):
    def __init__(self, learner, features, k):
        """Constructs a BaggedTree class with a set of learners. """
        self.learner = learner
        self.classes = [0,1]
        self.features = features
        self.k = k
        self.train_auc = None
        self.valid_auc = None
    
    def __str__(self):
        return 'k = {}, features = {}, training_auc = {}, validation_auc = {}'.format(self.k, self.features, self.train_auc, self.valid_auc)
    
    def set_train_auc(self, train_auc):
        self.train_auc = train_auc
        
    def set_valid_auc(self, valid_auc):
        self.valid_auc = valid_auc
        
    def get_train_auc(self):
        return self.train_auc
        
    def get_valid_auc(self):
        return self.valid_auc
    
    def predictSoft(self, X):
        """Predicts the probabilities with each bagged learner and average over the results. """
        return np.vstack((1-self.learner.predict(X[:,self.features]), self.learner.predict(X[:,self.features]))).T

# %%
class BaggedKNN(ml.base.classifier):
    def __init__(self, learners):
        """Constructs a BaggedKNN class with a set of learners. """
        self.learners = learners
        self.classes = [0,1]
        self.train_auc = None
        self.valid_auc = None
        self.total_auc = None
    
    def __str__(self):
        return 'Bagged KNN, training_auc = {}, validation_auc = {}'.format(self.train_auc, self.valid_auc)
    
    def set_train_auc(self, train_auc):
        self.train_auc = train_auc
        
    def set_valid_auc(self, valid_auc):
        self.valid_auc = valid_auc
        
    def get_train_auc(self):
        return self.train_auc
        
    def get_valid_auc(self):
        return self.valid_auc
    
    def predictSoft(self, X):
        """Predicts the probabilities with each bagged learner and average over the results. """
        return np.average([learner.predictSoft(X) for learner in self.learners], weights=[learner.get_valid_auc() for learner in self.learners], axis=0)

# %%
X = np.genfromtxt('data/X_train.txt', delimiter=',')
Y = np.genfromtxt('data/Y_train.txt', delimiter=',')
Xtr, Xva, Ytr, Yva = train_test_split(X,Y,shuffle=False)

# %%
best_ten_knn = []
best_bagged_knn = None

trial = 0
empty_run_count = 0
while empty_run_count == 0 or empty_run_count / trial < 0.7:
    flag = False
    print('Trial {}:'.format(trial+1))
    mutual_info = mutual_info_classif(X, Y)
    mutual_info_rank = np.argsort(mutual_info)[::-1]
    top_features = mutual_info_rank[:3]
    print('Top 3 Features:', top_features)
    
    feature_combo = []
    for i in range(1,4):
        feature_combo += list(itertools.combinations(top_features, i))
    # print('Feature Combo:', feature_combo)
    
    for idx in feature_combo:
        idx = np.array(idx)
        # print('Features:', idx)
        if mutual_info_rank[0] in idx:
            for k in range(1,101):
                Xtr, Xva, Ytr, Yva = train_test_split(X,Y)
                knn = KNeighborsRegressor(n_neighbors=k)
                knn.fit(Xtr[:,idx], Ytr)
                ml_knn = KNN(knn, idx, k)
                ml_train_auc = ml_knn.auc(Xtr,Ytr)
                ml_valid_auc = ml_knn.auc(Xva,Yva)
                # print('Current:', idx, k, ml_train_auc, ml_valid_auc)
                ml_knn.set_train_auc(ml_train_auc)
                ml_knn.set_valid_auc(ml_valid_auc)
                if len(best_ten_knn) < 10:
                    best_ten_knn.append(ml_knn)
                    # print('New Best 10 KNN:\n', ml_knn)
                    flag = True
                    if best_bagged_knn is None:
                        best_bagged_knn = BaggedKNN(best_ten_knn)
                        bagged_train_auc = best_bagged_knn.auc(Xtr,Ytr)
                        bagged_valid_auc = best_bagged_knn.auc(Xva,Yva)
                        best_bagged_knn.set_train_auc(bagged_train_auc)
                        best_bagged_knn.set_valid_auc(bagged_valid_auc)
                        print('New Best Bagged KNN:\n', best_bagged_knn)
                    else:
                        bagged_knn = BaggedKNN(best_ten_knn)
                        bagged_train_auc = bagged_knn.auc(Xtr,Ytr)
                        bagged_valid_auc = bagged_knn.auc(Xva,Yva)
                        bagged_knn.set_train_auc(bagged_train_auc)
                        bagged_knn.set_valid_auc(bagged_valid_auc)
                        if bagged_knn.get_valid_auc() > best_bagged_knn.get_valid_auc():
                            best_bagged_knn = bagged_knn
                            print('New Best Bagged KNN:\n', best_bagged_knn)
                else:
                    for top_knn in best_ten_knn:
                        if top_knn.get_valid_auc() < ml_knn.get_valid_auc():
                            best_ten_knn.append(ml_knn)
                            # print('New Best 10 KNN:\n', ml_knn)
                            flag = True
                            best_ten_knn = sorted(best_ten_knn, key = lambda x : x.get_valid_auc(), reverse = True)[:10]
                            bagged_knn = BaggedKNN(best_ten_knn)
                            bagged_train_auc = bagged_knn.auc(Xtr,Ytr)
                            bagged_valid_auc = bagged_knn.auc(Xva,Yva)
                            bagged_knn.set_train_auc(bagged_train_auc)
                            bagged_knn.set_valid_auc(bagged_valid_auc)
                            if bagged_knn.get_valid_auc() > best_bagged_knn.get_valid_auc():
                                best_bagged_knn = bagged_knn
                                print('New Best Bagged KNN:\n', best_bagged_knn)
                            break
    if not flag:
        empty_run_count += 1
    else:
        print('Best 10 KNN:\n', '\n '.join(str(x) for x in best_ten_knn))
        print('Best Bagged KNN:\n', best_bagged_knn)
    trial += 1
    print('Empty Run Count:', empty_run_count)
    print('Empty Run Ratio:', empty_run_count / trial)

print('\nTotal Trials:', trial)
print('Very Best KNN:\n', best_ten_knn[0])
print('Very Best Bagged KNN:\n', best_bagged_knn)
# Out:
# Trial 1:
# Top 3 Features: [28  7 56]
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.5619284329137958, validation_auc = 0.556074549307632
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6356348480138472, validation_auc = 0.6375989335612366
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6510063116319892, validation_auc = 0.6566020766713765
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6686671416641174, validation_auc = 0.6587748003945062
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6708871902728488, validation_auc = 0.6683883901556288
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6671670628243889, validation_auc = 0.6856963416548908
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.682528837415837, validation_auc = 0.6958209412811244
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6880143736132678, validation_auc = 0.6980242578141851
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6820670660785217, validation_auc = 0.7156204277851321
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6914359690719121, validation_auc = 0.7185390896802872
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7010822795840514, validation_auc = 0.7249254804147318
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6985494217564149, validation_auc = 0.7304051321856175
# Best 10 KNN:
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 94, features = [28 56], training_auc = 0.6970296412476645, validation_auc = 0.708913253819102
#  k = 67, features = [28 56], training_auc = 0.7015033143022407, validation_auc = 0.7069122700661856
#  k = 52, features = [28 56], training_auc = 0.7032566151730134, validation_auc = 0.7062067306966191
#  k = 14, features = [28 56], training_auc = 0.691049453711255, validation_auc = 0.7061591312133956
#  k = 63, features = [28 56], training_auc = 0.6991985050638059, validation_auc = 0.7058354612202052
#  k = 55, features = [28 56], training_auc = 0.6970537314943326, validation_auc = 0.7029920336306206
#  k = 33, features = [28 56], training_auc = 0.7006143221350889, validation_auc = 0.7013447368879443
#  k = 68, features = [28 56], training_auc = 0.6976079689194072, validation_auc = 0.7010015012642224
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6985494217564149, validation_auc = 0.7304051321856175
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 2:
# Top 3 Features: [28 95  9]
# Best 10 KNN:
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
#  k = 94, features = [28 56], training_auc = 0.6970296412476645, validation_auc = 0.708913253819102
#  k = 67, features = [28 56], training_auc = 0.7015033143022407, validation_auc = 0.7069122700661856
#  k = 52, features = [28 56], training_auc = 0.7032566151730134, validation_auc = 0.7062067306966191
#  k = 14, features = [28 56], training_auc = 0.691049453711255, validation_auc = 0.7061591312133956
#  k = 63, features = [28 56], training_auc = 0.6991985050638059, validation_auc = 0.7058354612202052
#  k = 55, features = [28 56], training_auc = 0.6970537314943326, validation_auc = 0.7029920336306206
#  k = 82, features = [28 95], training_auc = 0.6912098540551233, validation_auc = 0.7018628635138902
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6985494217564149, validation_auc = 0.7304051321856175
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 3:
# Top 3 Features: [28 56 96]
# Best 10 KNN:
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
#  k = 85, features = [28 56], training_auc = 0.6932863101152321, validation_auc = 0.7121850379708189
#  k = 51, features = [28 56 96], training_auc = 0.6906216684348969, validation_auc = 0.7097834999389404
#  k = 80, features = [28 56 96], training_auc = 0.6925121409041972, validation_auc = 0.709518351819854
#  k = 94, features = [28 56], training_auc = 0.6970296412476645, validation_auc = 0.708913253819102
#  k = 77, features = [28 96], training_auc = 0.6898622532846966, validation_auc = 0.7075026592409203
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6985494217564149, validation_auc = 0.7304051321856175
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 4:
# Top 3 Features: [28 82 56]
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6939403955901895, validation_auc = 0.7402722149776454
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
#  k = 85, features = [28 56], training_auc = 0.6932863101152321, validation_auc = 0.7121850379708189
#  k = 42, features = [28 82 56], training_auc = 0.6968556458837288, validation_auc = 0.7117294202359936
#  k = 51, features = [28 56 96], training_auc = 0.6906216684348969, validation_auc = 0.7097834999389404
#  k = 80, features = [28 56 96], training_auc = 0.6925121409041972, validation_auc = 0.709518351819854
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6939403955901895, validation_auc = 0.7402722149776454
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 5:
# Top 3 Features: [28 58 78]
# Empty Run Count: 1
# Empty Run Ratio: 0.2
# Trial 6:
# Top 3 Features: [28 56 96]
# Empty Run Count: 2
# Empty Run Ratio: 0.3333333333333333
# Trial 7:
# Top 3 Features: [28 59 56]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
#  k = 85, features = [28 56], training_auc = 0.6932863101152321, validation_auc = 0.7121850379708189
#  k = 42, features = [28 82 56], training_auc = 0.6968556458837288, validation_auc = 0.7117294202359936
#  k = 51, features = [28 56 96], training_auc = 0.6906216684348969, validation_auc = 0.7097834999389404
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6939403955901895, validation_auc = 0.7402722149776454
# Empty Run Count: 2
# Empty Run Ratio: 0.2857142857142857
# Trial 8:
# Top 3 Features: [28  7 56]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
#  k = 85, features = [28 56], training_auc = 0.6932863101152321, validation_auc = 0.7121850379708189
#  k = 25, features = [28 56], training_auc = 0.7003764165802462, validation_auc = 0.7118817090038708
#  k = 42, features = [28 82 56], training_auc = 0.6968556458837288, validation_auc = 0.7117294202359936
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6939403955901895, validation_auc = 0.7402722149776454
# Empty Run Count: 2
# Empty Run Ratio: 0.25
# Trial 9:
# Top 3 Features: [28 56 70]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
#  k = 85, features = [28 56], training_auc = 0.6932863101152321, validation_auc = 0.7121850379708189
#  k = 25, features = [28 56], training_auc = 0.7003764165802462, validation_auc = 0.7118817090038708
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6939403955901895, validation_auc = 0.7402722149776454
# Empty Run Count: 2
# Empty Run Ratio: 0.2222222222222222
# Trial 10:
# Top 3 Features: [28  9 14]
# Empty Run Count: 3
# Empty Run Ratio: 0.3
# Trial 11:
# Top 3 Features: [28 56 34]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 39, features = [28 56 34], training_auc = 0.6967205358779532, validation_auc = 0.7156768481875778
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
#  k = 85, features = [28 56], training_auc = 0.6932863101152321, validation_auc = 0.7121850379708189
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6939403955901895, validation_auc = 0.7402722149776454
# Empty Run Count: 3
# Empty Run Ratio: 0.2727272727272727
# Trial 12:
# Top 3 Features: [28 56  7]
# Empty Run Count: 4
# Empty Run Ratio: 0.3333333333333333
# Trial 13:
# Top 3 Features: [28  7 56]
# Empty Run Count: 5
# Empty Run Ratio: 0.38461538461538464
# Trial 14:
# Top 3 Features: [28 56 74]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 39, features = [28 56 34], training_auc = 0.6967205358779532, validation_auc = 0.7156768481875778
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 48, features = [28 56], training_auc = 0.6996248254176424, validation_auc = 0.7127793133884606
#  k = 42, features = [28 95], training_auc = 0.6893317277038207, validation_auc = 0.712277545118633
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.6939403955901895, validation_auc = 0.7402722149776454
# Empty Run Count: 5
# Empty Run Ratio: 0.35714285714285715
# Trial 15:
# Top 3 Features: [28  9 60]
# Empty Run Count: 6
# Empty Run Ratio: 0.4
# Trial 16:
# Top 3 Features: [28 56 64]
# Empty Run Count: 7
# Empty Run Ratio: 0.4375
# Trial 17:
# Top 3 Features: [28  7 47]
# Empty Run Count: 8
# Empty Run Ratio: 0.47058823529411764
# Trial 18:
# Top 3 Features: [ 28 103 105]
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.703156587207256, validation_auc = 0.7406065244227462
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 39, features = [28 56 34], training_auc = 0.6967205358779532, validation_auc = 0.7156768481875778
#  k = 96, features = [ 28 103 105], training_auc = 0.684838928079064, validation_auc = 0.7154260291742103
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
#  k = 48, features = [28 56], training_auc = 0.6996248254176424, validation_auc = 0.7127793133884606
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.703156587207256, validation_auc = 0.7406065244227462
# Empty Run Count: 8
# Empty Run Ratio: 0.4444444444444444
# Trial 19:
# Top 3 Features: [28  7 56]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 39, features = [28 56 34], training_auc = 0.6967205358779532, validation_auc = 0.7156768481875778
#  k = 96, features = [ 28 103 105], training_auc = 0.684838928079064, validation_auc = 0.7154260291742103
#  k = 46, features = [28 56], training_auc = 0.6990722608219025, validation_auc = 0.7151072662350858
#  k = 100, features = [28 56 96], training_auc = 0.6950981685428007, validation_auc = 0.7143833873757904
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.703156587207256, validation_auc = 0.7406065244227462
# Empty Run Count: 8
# Empty Run Ratio: 0.42105263157894735
# Trial 20:
# Top 3 Features: [28 56 71]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 35, features = [28 56], training_auc = 0.6978117682179199, validation_auc = 0.7158947174023386
#  k = 39, features = [28 56 34], training_auc = 0.6967205358779532, validation_auc = 0.7156768481875778
#  k = 96, features = [ 28 103 105], training_auc = 0.684838928079064, validation_auc = 0.7154260291742103
#  k = 46, features = [28 56], training_auc = 0.6990722608219025, validation_auc = 0.7151072662350858
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.703156587207256, validation_auc = 0.7406065244227462
# Empty Run Count: 8
# Empty Run Ratio: 0.4
# Trial 21:
# Top 3 Features: [28 56 59]
# Empty Run Count: 9
# Empty Run Ratio: 0.42857142857142855
# Trial 22:
# Top 3 Features: [28 69 59]
# Empty Run Count: 10
# Empty Run Ratio: 0.45454545454545453
# Trial 23:
# Top 3 Features: [28 96 46]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 35, features = [28 56], training_auc = 0.6978117682179199, validation_auc = 0.7158947174023386
#  k = 39, features = [28 56 34], training_auc = 0.6967205358779532, validation_auc = 0.7156768481875778
#  k = 96, features = [ 28 103 105], training_auc = 0.684838928079064, validation_auc = 0.7154260291742103
#  k = 84, features = [28 96], training_auc = 0.6868584193248927, validation_auc = 0.7151881458147488
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.703156587207256, validation_auc = 0.7406065244227462
# Empty Run Count: 10
# Empty Run Ratio: 0.43478260869565216
# Trial 24:
# Top 3 Features: [28 56  7]
# Empty Run Count: 11
# Empty Run Ratio: 0.4583333333333333
# Trial 25:
# Top 3 Features: [28  7 70]
# Empty Run Count: 12
# Empty Run Ratio: 0.48
# Trial 26:
# Top 3 Features: [ 28  89 103]
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 78, features = [28 89], training_auc = 0.6858115852981647, validation_auc = 0.7168859750998792
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 85, features = [ 28  89 103], training_auc = 0.6782933231080676, validation_auc = 0.7167160209959123
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
#  k = 35, features = [28 56], training_auc = 0.6978117682179199, validation_auc = 0.7158947174023386
#  k = 39, features = [28 56 34], training_auc = 0.6967205358779532, validation_auc = 0.7156768481875778
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Empty Run Count: 12
# Empty Run Ratio: 0.46153846153846156
# Trial 27:
# Top 3 Features: [28 80  9]
# Empty Run Count: 13
# Empty Run Ratio: 0.48148148148148145
# Trial 28:
# Top 3 Features: [28 59 68]
# Empty Run Count: 14
# Empty Run Ratio: 0.5
# Trial 29:
# Top 3 Features: [28 87 68]
# Empty Run Count: 15
# Empty Run Ratio: 0.5172413793103449
# Trial 30:
# Top 3 Features: [28  7 88]
# Empty Run Count: 16
# Empty Run Ratio: 0.5333333333333333
# Trial 31:
# Top 3 Features: [28 59 23]
# Empty Run Count: 17
# Empty Run Ratio: 0.5483870967741935
# Trial 32:
# Top 3 Features: [28 91 56]
# Empty Run Count: 18
# Empty Run Ratio: 0.5625
# Trial 33:
# Top 3 Features: [28 59 56]
# Empty Run Count: 19
# Empty Run Ratio: 0.5757575757575758
# Trial 34:
# Top 3 Features: [28  7 33]
# Empty Run Count: 20
# Empty Run Ratio: 0.5882352941176471
# Trial 35:
# Top 3 Features: [28 56 46]
# Empty Run Count: 21
# Empty Run Ratio: 0.6
# Trial 36:
# Top 3 Features: [28 56 46]
# Empty Run Count: 22
# Empty Run Ratio: 0.6111111111111112
# Trial 37:
# Top 3 Features: [28 56 60]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 33, features = [28 56], training_auc = 0.6832026560968122, validation_auc = 0.7187128044879052
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 78, features = [28 89], training_auc = 0.6858115852981647, validation_auc = 0.7168859750998792
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 85, features = [ 28  89 103], training_auc = 0.6782933231080676, validation_auc = 0.7167160209959123
#  k = 87, features = [28 56], training_auc = 0.6889406974156577, validation_auc = 0.7160781171059738
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Empty Run Count: 22
# Empty Run Ratio: 0.5945945945945946
# Trial 38:
# Top 3 Features: [ 28   7 106]
# Empty Run Count: 23
# Empty Run Ratio: 0.6052631578947368
# Trial 39:
# Top 3 Features: [28 56 58]
# Empty Run Count: 24
# Empty Run Ratio: 0.6153846153846154
# Trial 40:
# Top 3 Features: [28 56 57]
# Empty Run Count: 25
# Empty Run Ratio: 0.625
# Trial 41:
# Top 3 Features: [28 56  9]
# Empty Run Count: 26
# Empty Run Ratio: 0.6341463414634146
# Trial 42:
# Top 3 Features: [28 56 59]
# Empty Run Count: 27
# Empty Run Ratio: 0.6428571428571429
# Trial 43:
# Top 3 Features: [28 56 99]
# Empty Run Count: 28
# Empty Run Ratio: 0.6511627906976745
# Trial 44:
# Top 3 Features: [28  7 56]
# Empty Run Count: 29
# Empty Run Ratio: 0.6590909090909091
# Trial 45:
# Top 3 Features: [28 73 56]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 99, features = [28 73 56], training_auc = 0.6893167313808913, validation_auc = 0.7190585795195232
#  k = 33, features = [28 56], training_auc = 0.6832026560968122, validation_auc = 0.7187128044879052
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 78, features = [28 89], training_auc = 0.6858115852981647, validation_auc = 0.7168859750998792
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
#  k = 85, features = [ 28  89 103], training_auc = 0.6782933231080676, validation_auc = 0.7167160209959123
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Empty Run Count: 29
# Empty Run Ratio: 0.6444444444444445
# Trial 46:
# Top 3 Features: [28  7  9]
# Empty Run Count: 30
# Empty Run Ratio: 0.6521739130434783
# Trial 47:
# Top 3 Features: [28 56  7]
# Empty Run Count: 31
# Empty Run Ratio: 0.6595744680851063
# Trial 48:
# Top 3 Features: [28 85 70]
# Empty Run Count: 32
# Empty Run Ratio: 0.6666666666666666
# Trial 49:
# Top 3 Features: [28  7 56]
# Empty Run Count: 33
# Empty Run Ratio: 0.673469387755102
# Trial 50:
# Top 3 Features: [28  7 87]
# Empty Run Count: 34
# Empty Run Ratio: 0.68
# Trial 51:
# Top 3 Features: [28 56 59]
# Empty Run Count: 35
# Empty Run Ratio: 0.6862745098039216
# Trial 52:
# Top 3 Features: [28 56  7]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 99, features = [28 73 56], training_auc = 0.6893167313808913, validation_auc = 0.7190585795195232
#  k = 33, features = [28 56], training_auc = 0.6832026560968122, validation_auc = 0.7187128044879052
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 58, features = [28 56], training_auc = 0.6982121461603817, validation_auc = 0.7171019319834069
#  k = 78, features = [28 89], training_auc = 0.6858115852981647, validation_auc = 0.7168859750998792
#  k = 80, features = [28 56], training_auc = 0.696669549279777, validation_auc = 0.716873419721871
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Empty Run Count: 35
# Empty Run Ratio: 0.6730769230769231
# Trial 53:
# Top 3 Features: [28 56 42]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 16, features = [28 56 42], training_auc = 0.7052510526088874, validation_auc = 0.7220933149379155
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 99, features = [28 73 56], training_auc = 0.6893167313808913, validation_auc = 0.7190585795195232
#  k = 33, features = [28 56], training_auc = 0.6832026560968122, validation_auc = 0.7187128044879052
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 58, features = [28 56], training_auc = 0.6982121461603817, validation_auc = 0.7171019319834069
#  k = 78, features = [28 89], training_auc = 0.6858115852981647, validation_auc = 0.7168859750998792
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Empty Run Count: 35
# Empty Run Ratio: 0.660377358490566
# Trial 54:
# Top 3 Features: [28 95  7]
# Empty Run Count: 36
# Empty Run Ratio: 0.6666666666666666
# Trial 55:
# Top 3 Features: [28 56 59]
# Empty Run Count: 37
# Empty Run Ratio: 0.6727272727272727
# Trial 56:
# Top 3 Features: [28 56 67]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 16, features = [28 56 42], training_auc = 0.7052510526088874, validation_auc = 0.7220933149379155
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 24, features = [28 56], training_auc = 0.6920439247022809, validation_auc = 0.7197167103282983
#  k = 99, features = [28 73 56], training_auc = 0.6893167313808913, validation_auc = 0.7190585795195232
#  k = 33, features = [28 56], training_auc = 0.6832026560968122, validation_auc = 0.7187128044879052
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
#  k = 64, features = [28 56 96], training_auc = 0.6986343403699621, validation_auc = 0.7175059350420679
#  k = 58, features = [28 56], training_auc = 0.6982121461603817, validation_auc = 0.7171019319834069
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Empty Run Count: 37
# Empty Run Ratio: 0.6607142857142857
# Trial 57:
# Top 3 Features: [28 56 79]
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 17, features = [28 56 79], training_auc = 0.6979949953953196, validation_auc = 0.7246442360728075
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 16, features = [28 56 42], training_auc = 0.7052510526088874, validation_auc = 0.7220933149379155
#  k = 40, features = [28 56 79], training_auc = 0.7022041426724902, validation_auc = 0.7212700090607067
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 24, features = [28 56], training_auc = 0.6920439247022809, validation_auc = 0.7197167103282983
#  k = 99, features = [28 73 56], training_auc = 0.6893167313808913, validation_auc = 0.7190585795195232
#  k = 33, features = [28 56], training_auc = 0.6832026560968122, validation_auc = 0.7187128044879052
#  k = 52, features = [28 56 70], training_auc = 0.702597460096019, validation_auc = 0.7178756479692994
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7005317912806371, validation_auc = 0.7454762402452619
# Empty Run Count: 37
# Empty Run Ratio: 0.6491228070175439
# Trial 58:
# Top 3 Features: [28 59  9]
# Empty Run Count: 38
# Empty Run Ratio: 0.6551724137931034
# Trial 59:
# Top 3 Features: [28 56  7]
# Empty Run Count: 39
# Empty Run Ratio: 0.6610169491525424
# Trial 60:
# Top 3 Features: [28 92  9]
# Empty Run Count: 40
# Empty Run Ratio: 0.6666666666666666
# Trial 61:
# Top 3 Features: [ 28 100   7]
# Empty Run Count: 41
# Empty Run Ratio: 0.6721311475409836
# Trial 62:
# Top 3 Features: [28 56 82]
# Empty Run Count: 42
# Empty Run Ratio: 0.6774193548387096
# Trial 63:
# Top 3 Features: [ 28 100  35]
# New Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7057581989113381, validation_auc = 0.7505352933454004
# Best 10 KNN:
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 17, features = [28 56 79], training_auc = 0.6979949953953196, validation_auc = 0.7246442360728075
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 16, features = [28 56 42], training_auc = 0.7052510526088874, validation_auc = 0.7220933149379155
#  k = 40, features = [28 56 79], training_auc = 0.7022041426724902, validation_auc = 0.7212700090607067
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 39, features = [28], training_auc = 0.6810450401239524, validation_auc = 0.7200465179501895
#  k = 24, features = [28 56], training_auc = 0.6920439247022809, validation_auc = 0.7197167103282983
#  k = 99, features = [28 73 56], training_auc = 0.6893167313808913, validation_auc = 0.7190585795195232
#  k = 33, features = [28 56], training_auc = 0.6832026560968122, validation_auc = 0.7187128044879052
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7057581989113381, validation_auc = 0.7505352933454004
# Empty Run Count: 42
# Empty Run Ratio: 0.6666666666666666
# Trial 64:
# Top 3 Features: [28 59  7]
# Empty Run Count: 43
# Empty Run Ratio: 0.671875
# Trial 65:
# Top 3 Features: [28 78 72]
# Empty Run Count: 44
# Empty Run Ratio: 0.676923076923077
# Trial 66:
# Top 3 Features: [28 56 46]
# Empty Run Count: 45
# Empty Run Ratio: 0.6818181818181818
# Trial 67:
# Top 3 Features: [28  7 23]
# Empty Run Count: 46
# Empty Run Ratio: 0.6865671641791045
# Trial 68:
# Top 3 Features: [28 47 56]
# Best 10 KNN:
#  k = 58, features = [28 56], training_auc = 0.6926510852462182, validation_auc = 0.7289553257900898
#  k = 90, features = [28 56], training_auc = 0.6880618357482935, validation_auc = 0.7285546292846498
#  k = 17, features = [28 56 79], training_auc = 0.6979949953953196, validation_auc = 0.7246442360728075
#  k = 45, features = [28 56], training_auc = 0.6872326252396351, validation_auc = 0.7244099105532738
#  k = 16, features = [28 56 42], training_auc = 0.7052510526088874, validation_auc = 0.7220933149379155
#  k = 40, features = [28 56 79], training_auc = 0.7022041426724902, validation_auc = 0.7212700090607067
#  k = 93, features = [28 60], training_auc = 0.6821959673704454, validation_auc = 0.7201809240130758
#  k = 39, features = [28], training_auc = 0.6810450401239524, validation_auc = 0.7200465179501895
#  k = 24, features = [28 56], training_auc = 0.6920439247022809, validation_auc = 0.7197167103282983
#  k = 99, features = [28 73 56], training_auc = 0.6893167313808913, validation_auc = 0.7190585795195232
# Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7057581989113381, validation_auc = 0.7505352933454004
# Empty Run Count: 46
# Empty Run Ratio: 0.6764705882352942
# Trial 69:
# Top 3 Features: [28  7 59]
# Empty Run Count: 47
# Empty Run Ratio: 0.6811594202898551
# Trial 70:
# Top 3 Features: [28 72 59]
# Empty Run Count: 48
# Empty Run Ratio: 0.6857142857142857
# Trial 71:
# Top 3 Features: [28 56 27]
# Empty Run Count: 49
# Empty Run Ratio: 0.6901408450704225
# Trial 72:
# Top 3 Features: [28 56 59]
# Empty Run Count: 50
# Empty Run Ratio: 0.6944444444444444
# Trial 73:
# Top 3 Features: [28 99 52]
# Empty Run Count: 51
# Empty Run Ratio: 0.6986301369863014
# Trial 74:
# Top 3 Features: [28 73 56]
# Empty Run Count: 52
# Empty Run Ratio: 0.7027027027027027
#
# Total Trials: 74
# Very Best KNN:
#  k = 58, features = [28 56], training_auc = 0.6926510852462182, validation_auc = 0.7289553257900898
# Very Best Bagged KNN:
#  Bagged KNN, training_auc = 0.7057581989113381, validation_auc = 0.7505352933454004

# %%
Xte = np.genfromtxt('data/X_test.txt', delimiter=',')
print('Predicting using:', best_ten_knn[0])
Yte = np.vstack((np.arange(Xte.shape[0]), best_ten_knn[0].predictSoft(Xte)[:,1])).T
np.savetxt('Y_KNN_submit.txt',Yte,'%d, %.2f',header='Id,Predicted',comments='',delimiter=',')
# Out:
# Predicting using: k = 58, features = [28 56], training_auc = 0.6926510852462182, validation_auc = 0.7289553257900898

# %%
Xte = np.genfromtxt('data/X_test.txt', delimiter=',')
print('Predicting using:', best_bagged_knn)
Yte = np.vstack((np.arange(Xte.shape[0]), best_bagged_knn.predictSoft(Xte)[:,1])).T
np.savetxt('Y_Bagged_KNN_submit.txt',Yte,'%d, %.2f',header='Id,Predicted',comments='',delimiter=',')
# Out:
# Predicting using: Bagged KNN, training_auc = 0.7057581989113381, validation_auc = 0.7505352933454004

# %% [markdown]
# # Neural Network

# %%
class NN(ml.base.classifier):
    def __init__(self, learner, features, layers):
        """Constructs a BaggedTree class with a set of learners. """
        self.learner = learner
        self.classes = [0,1]
        self.features = features
        self.layers = layers
        self.train_auc = None
        self.valid_auc = None
        self.total_auc = None
        
    def __str__(self):
        return 'layers = {}, features = {}, training_auc = {}, validation_auc = {}'.format(self.layers, self.features, self.train_auc, self.valid_auc)
    
    def set_train_auc(self, train_auc):
        self.train_auc = train_auc
        
    def set_valid_auc(self, valid_auc):
        self.valid_auc = valid_auc
        
    def get_train_auc(self):
        return self.train_auc
        
    def get_valid_auc(self):
        return self.valid_auc
    
    def predictSoft(self, X):
        """Predicts the probabilities with each bagged learner and average over the results. """
        return np.vstack((1-self.learner.predict(X[:,self.features]), self.learner.predict(X[:,self.features]))).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-554542573d92> in <module>
# ----> 1 class NN(ml.base.classifier):
#       2     def __init__(self, learner, features, layers):
#       3         """Constructs a BaggedTree class with a set of learners. """
#       4         self.learner = learner
#       5         self.classes = [0,1]
#
# NameError: name 'ml' is not defined

# %%
X = np.genfromtxt('data/X_train.txt', delimiter=',')
Y = np.genfromtxt('data/Y_train.txt', delimiter=',')
Xtr, Xva, Ytr, Yva = train_test_split(X,Y,shuffle=False)

# %%
best_nn = None

trial = 0
empty_run_count = 0
while empty_run_count < 1:
    flag = False
    print('Trial {}:'.format(trial+1))
    mutual_info = mutual_info_classif(X, Y)
    mutual_info_rank = np.argsort(mutual_info)[::-1]
    top_features = mutual_info_rank[:3]
    print('Top 3 Features:', top_features)

    feature_combo = []
    for i in range(1,4):
        feature_combo += list(itertools.combinations(top_features, i))
    # print('Feature Combo:', feature_combo)
    
    layers_combo = list(itertools.combinations([800, 500, 300, 200, 100], 2))
    # print('Layers Combo:', layers_combo)
    
    for idx in feature_combo:
        idx = np.array(idx)
        print('Features:', idx)
        if mutual_info_rank[0] in idx:
            for layers in layers_combo:
                nn = MLPRegressor(hidden_layer_sizes=layers, activation='logistic', solver='adam')
                nn.fit(Xtr[:,idx], Ytr)
                ml_nn = NN(nn, idx, layers)
                ml_train_auc = ml_nn.auc(Xtr,Ytr)
                ml_valid_auc = ml_nn.auc(Xva,Yva)
                ml_nn.set_train_auc(ml_train_auc)
                ml_nn.set_valid_auc(ml_valid_auc)
                if best_nn is None:
                    best_nn = ml_nn
                    print('New Best NN:\n', ml_nn)
                    flag = True
                else:
                    if best_nn.get_valid_auc() < ml_nn.get_valid_auc():
                        best_nn = ml_nn
                        print('New Best NN:\n', ml_nn)
                        flag = True
    if not flag:
        empty_run_count += 1
    trial += 1
    print('Empty Run Count:', empty_run_count)
    print('Empty Run Ratio:', empty_run_count / trial)

print('\nTotal Trials:', trial)
print('Very Best NN:\n', best_nn)
# Out:
# Trial 1:
# Top 3 Features: [28 59 56]
# Features: [28]
# New Best NN:
#  layers = (800, 500), features = [28], training_auc = 0.5337634131306185, validation_auc = 0.526341017873266
# New Best NN:
#  layers = (800, 300), features = [28], training_auc = 0.6724490786346073, validation_auc = 0.6546053204951665
# New Best NN:
#  layers = (800, 200), features = [28], training_auc = 0.6839802148579076, validation_auc = 0.6741873596116013
# New Best NN:
#  layers = (500, 300), features = [28], training_auc = 0.6882044733152014, validation_auc = 0.6760239565212844
# Features: [59]
# Features: [56]
# Features: [28 59]
# Features: [28 56]
# New Best NN:
#  layers = (800, 500), features = [28 56], training_auc = 0.6926245980707395, validation_auc = 0.6794200049037893
# New Best NN:
#  layers = (500, 300), features = [28 56], training_auc = 0.6942306371804959, validation_auc = 0.6800672586074865
# Features: [59 56]
# Features: [28 59 56]
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 2:
# Top 3 Features: [28  7 87]
# Features: [28]
# Features: [7]
# Features: [87]
# Features: [28  7]
# Features: [28 87]
# New Best NN:
#  layers = (800, 300), features = [28 87], training_auc = 0.6849711628017437, validation_auc = 0.6868837581153645
# Features: [ 7 87]
# Features: [28  7 87]
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 3:
# Top 3 Features: [28 80 56]
# Features: [28]
# Features: [80]
# Features: [56]
# Features: [28 80]
# Features: [28 56]
# New Best NN:
#  layers = (800, 100), features = [28 56], training_auc = 0.6915450424077964, validation_auc = 0.6893397198797526
# Features: [80 56]
# Features: [28 80 56]
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 4:
# Top 3 Features: [ 28  58 100]
# Features: [28]
# Features: [58]
# Features: [100]
# Features: [28 58]
# Features: [ 28 100]
# Features: [ 58 100]
# Features: [ 28  58 100]
# Empty Run Count: 1
# Empty Run Ratio: 0.25
#
# Total Trials: 4
# Very Best NN:
#  layers = (800, 100), features = [28 56], training_auc = 0.6915450424077964, validation_auc = 0.6893397198797526

# %%
Xte = np.genfromtxt('data/X_test.txt', delimiter=',')
print('Predicting using:', best_nn)
Yte = np.vstack((np.arange(Xte.shape[0]), best_nn.predictSoft(Xte)[:,1])).T
np.savetxt('Y_NN_submit.txt',Yte,'%d, %.2f',header='Id,Predicted',comments='',delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0bbb51b5e200> in <module>
#       1 Xte = np.genfromtxt('data/X_test.txt', delimiter=',')
# ----> 2 print('Predicting using:', best_ten_nn[0])
#       3 Yte = np.vstack((np.arange(Xte.shape[0]), best_ten_nn[0].predictSoft(Xte)[:,1])).T
#       4 np.savetxt('Y_NN_submit.txt',Yte,'%d, %.2f',header='Id,Predicted',comments='',delimiter=',')
#
# NameError: name 'best_ten_nn' is not defined

# %% [markdown]
# # AdaBoost

# %%
class AB(ml.base.classifier):
    def __init__(self, learner, learning_rate):
        """Constructs a BaggedTree class with a set of learners. """
        self.learner = learner
        self.classes = [0,1]
        self.learning_rate = learning_rate
        self.train_auc = None
        self.valid_auc = None
        self.total_auc = None
        
    def __str__(self):
        return 'learning rate = {}, training_auc = {}, validation_auc = {}'.format(self.learning_rate, self.train_auc, self.valid_auc)
    
    def set_train_auc(self, train_auc):
        self.train_auc = train_auc
        
    def set_valid_auc(self, valid_auc):
        self.valid_auc = valid_auc
        
    def get_train_auc(self):
        return self.train_auc
        
    def get_valid_auc(self):
        return self.valid_auc
    
    def predictSoft(self, X):
        """Predicts the probabilities with each bagged learner and average over the results. """
        return np.vstack((1-self.learner.predict(X), self.learner.predict(X))).T

# %%
X = np.genfromtxt('data/X_train.txt', delimiter=',')
Y = np.genfromtxt('data/Y_train.txt', delimiter=',')
Xtr, Xva, Ytr, Yva = train_test_split(X,Y,shuffle=False)

# %%
best_ab = None

trial = 0
empty_run_count = 0
while empty_run_count == 0 or empty_run_count / trial < 0.7:
    flag = False
    print('Trial {}:'.format(trial+1))
    for lr in np.arange(0.01,1.01,0.03):
        ab = AdaBoostRegressor(n_estimators=300, loss='exponential', learning_rate=lr)
        ab.fit(Xtr, Ytr)
        ml_ab = AB(ab, round(lr,2))
        ml_train_auc = ml_ab.auc(Xtr,Ytr)
        ml_valid_auc = ml_ab.auc(Xva,Yva)
        ml_ab.set_train_auc(ml_train_auc)
        ml_ab.set_valid_auc(ml_valid_auc)
        if best_ab is None:
            best_ab = ml_ab
            print('New Best AB:\n', best_ab)
            flag = True
        else:
            if best_ab.get_valid_auc() < ml_ab.get_valid_auc():
                best_ab = ml_ab
                print('New Best AB:\n', best_ab)
                flag = True    
    if not flag:
        empty_run_count += 1
    trial += 1
    print('Empty Run Count:', empty_run_count)
    print('Empty Run Ratio:', empty_run_count / trial)

print('\nTotal Trials:', trial)
print('Very Best AB:\n', best_ab)
# Out:
# Trial 1:
# New Best AB:
#  learning rate = 0.01, training_auc = 0.7403634426622225, validation_auc = 0.710876883514088
# New Best AB:
#  learning rate = 0.04, training_auc = 0.7596630170353987, validation_auc = 0.7320323185278406
# New Best AB:
#  learning rate = 0.07, training_auc = 0.7709950601680617, validation_auc = 0.7351947978000346
# New Best AB:
#  learning rate = 0.1, training_auc = 0.770866311151588, validation_auc = 0.7353824665130456
# New Best AB:
#  learning rate = 0.13, training_auc = 0.7730929269743323, validation_auc = 0.7354678761130846
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 2:
# New Best AB:
#  learning rate = 0.46, training_auc = 0.7650584720595919, validation_auc = 0.7361174538875312
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 3:
# New Best AB:
#  learning rate = 0.1, training_auc = 0.7783931916229371, validation_auc = 0.7377681251372654
# New Best AB:
#  learning rate = 0.19, training_auc = 0.783222215510494, validation_auc = 0.7383177678694894
# Empty Run Count: 0
# Empty Run Ratio: 0.0
# Trial 4:
# Empty Run Count: 1
# Empty Run Ratio: 0.25
# Trial 5:
# Empty Run Count: 2
# Empty Run Ratio: 0.4
# Trial 6:
# New Best AB:
#  learning rate = 0.61, training_auc = 0.7780091387923432, validation_auc = 0.7384281612300841
# Empty Run Count: 2
# Empty Run Ratio: 0.3333333333333333
# Trial 7:
# Empty Run Count: 3
# Empty Run Ratio: 0.42857142857142855
# Trial 8:
# Empty Run Count: 4
# Empty Run Ratio: 0.5
# Trial 9:
# Empty Run Count: 5
# Empty Run Ratio: 0.5555555555555556
# Trial 10:
# Empty Run Count: 6
# Empty Run Ratio: 0.6
# Trial 11:
# Empty Run Count: 7
# Empty Run Ratio: 0.6363636363636364
# Trial 12:
# Empty Run Count: 8
# Empty Run Ratio: 0.6666666666666666
# Trial 13:
# Empty Run Count: 9
# Empty Run Ratio: 0.6923076923076923
# Trial 14:
# Empty Run Count: 10
# Empty Run Ratio: 0.7142857142857143
#
# Total Trials: 14
# Very Best AB:
#  learning rate = 0.61, training_auc = 0.7780091387923432, validation_auc = 0.7384281612300841

# %%
Xte = np.genfromtxt('data/X_test.txt', delimiter=',')
print('Predicting using:', best_ab)
Yte = np.vstack((np.arange(Xte.shape[0]), best_ab.predictSoft(Xte)[:,1])).T
np.savetxt('Y_AB_submit.txt',Yte,'%d, %.2f',header='Id,Predicted',comments='',delimiter=',')
# Out:
# Predicting using: learning rate = 0.61, training_auc = 0.7780091387923432, validation_auc = 0.7384281612300841
